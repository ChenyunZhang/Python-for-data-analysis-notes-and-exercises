# %%
import matplotlib.pyplot as plt

# %% [markdown]
# %matplotlib inilne

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x ** 2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,"red")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("String Title")
plt.show()

# %%
# plt.subplot(nrows, ncols, plot_number)
plt.subplot(1,2,1)
plt.plot(x, y, 'r--');
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.6,0.5,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5,0.4,0.3])

axes1.plot(x, y, 'b')
axes1.set_xlabel("X_label_1")
axes1.set_ylabel("Y_label_1")
axes1.set_title("Axies 1 Title")

# Insert Figure Axes 2
axes2.plot(y, x, 'r')
axes2.set_xlabel('X_label_axes2')
axes2.set_ylabel('Y_label_axes2')
axes2.set_title('Axes 2 Title');

# %%
fig,axes = plt.subplots()
axes.plot(x,y,"r")
axes.set_xlabel("x")
axes.set_ylabel("y")
axes.set_title("title")
# Out:
# Text(0.5, 1.0, 'title')

# %%
fig,axes = plt.subplots(nrows=1,ncols=2)

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fa2cc29ee80>,
# ...
#       dtype=object)

# %%
for ax in axes:
    ax.plot(x,y,"b")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_title("title")
    
fig

# %%
fig,axes = plt.subplots(nrows=2,ncols=1)

for ax in axes:
    ax.plot(x,y,"g")
    ax.set_xlabel("x")
    ax.set_ylabel("y")
    ax.set_title("title")

fig
plt.tight_layout()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,x**2,label="X square")
ax.plot(x,y*2,label="Y 2times")
# ax.legend(loc=0)
ax.legend(loc=(0.2,0.2))

# %%
fig.savefig("file.png",dpi=200)

# %%
a = np.linspace(0,1,20)
b = a**2

# %%
fig=plt.figure()
ax = fig.add_axes([0,0,1,1])
# ax.plot(a,b,color="g",linewidth=4,alpha=0.5,linestyle="--",markersize=2)
ax.plot(a,b,color="g",lw=2,alpha=0.8,ls="--",marker="o",ms=10,markerfacecolor="blue")
ax.set_xlim=([0,2])
ax.set_ylim=([0,2])
